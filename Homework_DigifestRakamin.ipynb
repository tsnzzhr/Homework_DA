# %% [markdown]
# ### Homework Rakamin Trial Class - Mini Case

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Mengukur Performa Penjualan Ritel Online

# %% [markdown]
# ## Load Data

# %%
## KOLOM 1
dframe = pd.read_csv("online_retail_II.csv")
dframe
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
## KOLOM 2
dframe.describe().round(3).T
# Out:
#                  count       mean       std       min       25%      50%  \
# Quantity     1067371.0      9.939   172.706 -80995.00      1.00      3.0
# Price        1067371.0      4.649   123.553 -53594.36      1.25      2.1
# Customer ID   824364.0  15324.639  1697.464  12346.00  13975.00  15255.0
#
#                   75%      max
# Quantity        10.00  80995.0
# Price            4.15  38970.0
# Customer ID  16797.00  18287.0

# %%
## KOLOM 3
dframe[dframe['Price'] < 0]
# Out:
#         Invoice StockCode      Description  Quantity          InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1  2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1  2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1  2010-10-20 12:04:00
# 825444  A563186         B  Adjust bad debt         1  2011-08-12 14:51:00
# 825445  A563187         B  Adjust bad debt         1  2011-08-12 14:52:00
#
#            Price  Customer ID         Country
# 179403 -53594.36          NaN  United Kingdom
# 276274 -44031.79          NaN  United Kingdom
# 403472 -38925.87          NaN  United Kingdom
# 825444 -11062.06          NaN  United Kingdom
# 825445 -11062.06          NaN  United Kingdom

# %%
## KOLOM 4
dframe[dframe['Quantity'] < 0]
# Out:
#          Invoice StockCode                       Description  Quantity  \
# 178      C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179      C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180      C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181      C489449     21896                POTTING SHED TWINE        -6
# 182      C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...          ...       ...                               ...       ...
# 1065910  C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 1067002  C581499         M                            Manual        -1
# 1067176  C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 1067177  C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 1067178  C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                  InvoiceDate   Price  Customer ID         Country
# ...

# %%
## KOLOM 5
dframe.shape
# Out:
# (1067371, 8)

# %% [markdown]
# ## Section 1

# %% [markdown]
# ### Create New Feature: Year

# %%
dframe['Year'] = pd.DatetimeIndex(dframe['InvoiceDate']).year
#dframe['Year']

# %% [markdown]
# ### Filtering Data

# %% [markdown]
# ### Create New Feature: Revenue

# %%
dframe['Revenue'] = dframe['Price'] * dframe['Quantity']
#dframe['Revenue']

# %% [markdown]
# ### Average of Revenue per Year

# %%
avg_revenue = dframe.groupby('Year').aggregate({"Revenue": lambda Revenue: Revenue.sum()})
# avg_revenue

# %% [markdown]
# ### Interpretation

# %% [markdown]
# 1. Pada Section 'Load Data' dilakukan import data csv dan pengecekan atribut-atribut, serta jumlah/banyak pada data
# 2. Pada Section 'Load Data' juga dilakukan pengecekan lokasi data yang hilang dan atau data yang memiliki nilai tidak wajar (contoh: Harga dan Kuantitas Barang yang negatif)
# 3. Pada Section 'Load Data' ditemukan bahwa ada beberapa data yang memiliki kode invoice khusus
# 4. untuk data 'Bad Debt' atau hutang dideskripsikan dengan tambahan karakter string 'A' di kode invoicenya. adapun data dengan Purchase Cancellation ditandai oleh karakter string 'C'
# 5. Pada Section 1 : **Create New Feature : Year** dilakukan penambahan kolom pada data original dengan mengambil tahun dari data bertipe DateTime di atribut **Invoice Date**.
# 6. Pada Section 1 : **Create New Feature : Revenue** dilakukan penambahan kolom pada data original dengan mengkalikan tiap harga barang **Price** dengan **Quantity**nya
# 7. Pada Section 1 : **Avg Revenue Per Year** dilakukan dengan menampilkan summary dari revenue/pendapatan pertahun dengan agregasi kolom revenue dengan SUM dan pengelompokan berdasarkan tahun.

# %% [markdown]
# ## Section 2

# %% [markdown]
# ### Filtering Data

# %% [markdown]
# #### Customers who finished their purchases

# %%
dframe[(dframe['Invoice'].str.contains('A') == False) & (dframe['Invoice'].str.contains('C') == False) ]
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year  \
# ...

# %% [markdown]
# #### Customers who canceled their purchases

# %%
dframe[(dframe['Invoice'].str.contains('C') == True)]
# Out:
#          Invoice StockCode                       Description  Quantity  \
# 178      C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179      C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180      C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181      C489449     21896                POTTING SHED TWINE        -6
# 182      C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...          ...       ...                               ...       ...
# 1065910  C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 1067002  C581499         M                            Manual        -1
# 1067176  C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 1067177  C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 1067178  C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                  InvoiceDate   Price  Customer ID         Country  Year  \
# ...

# %% [markdown]
# ### Number of Finished and Canceled Transactions Each Year

# %%
conditions = [
    (dframe['Invoice'].str.contains('A') == True),
    (dframe['Invoice'].str.contains('C') == True)]
choices = ['Adjust Debt', 'Cancelled']
dframe['Status'] = np.select(conditions, choices, default='Finished')
dframe
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year  \
# ...

# %%
dframe.groupby(['Status', 'Year'])['Invoice'].count()[2:]
# Out:
# Status     Year
# Cancelled  2009      1015
#            2010      9919
#            2011      8560
# Finished   2009     44213
#            2010    512792
#            2011    490866
# Name: Invoice, dtype: int64

# %% [markdown]
# ### Cancellation Rate

# %%
# cancel/total_invoice * 100%

cancel_amount = dframe.groupby(dframe['Status'] == 'Cancelled')["Invoice"].nunique()[1:]
total_invoice = dframe["Invoice"].nunique()

C_Rate = int(cancel_amount)/int(total_invoice)

print(f"{C_Rate:.0%}")
# Out:
# 15%

# %% [markdown]
# ### Interpretation

# %% [markdown]
# 1. Seperti yang telah diketahui dalam **Section 1** untuk mencari data In-Debt, Finished atau Cancelled bisa diekstrak melalui kode invoice.
# 2. **Section 2: Customers who had purchased** Pada pencarian data customer yang sudah melunasi transaksi bisa dilakukan pengecualian visualisasi terhadap data 'Cancelled' dan 'In-Debt'
# 3. **Section 2: Customers who canceled their purchases** bisa dilakukan dengan langsung mengambil karakter C pada kode invoice
# 4. **Section 2: Number of Finished and Canceled Transactions Each Year** Pada seleksi data antara 'Cancelled dan Finish' bisa dilakukan excluding terhadap data 'In-Debt' dengan manipulasi Array python terhadap hasil query
# 5. **Section 2 : Cancellation Rate** dapat dilakukan dengan rumus handcoded dengan menghitung jumlah invoice secara unik dari keseluruhan transaksi dibatalkan dibagi dengan jumlah transaksi keseluruhan dan dikalikan dengan 100%.
